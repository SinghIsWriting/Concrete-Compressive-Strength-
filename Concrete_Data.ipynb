# %%
# Importing the libraries to read and analyse the data
import pandas as pd
import numpy as np

# %%
# Reading the csv file of data
df = pd.read_csv("Concrete_Data_Sheet2.csv")

# %%
# Printing the dataframe
df
# Out:
#       Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0      540.0                 0.0      0.0  162.0               2.5
# 1      540.0                 0.0      0.0  162.0               2.5
# 2      332.5               142.5      0.0  228.0               0.0
# 3      332.5               142.5      0.0  228.0               0.0
# 4      198.6               132.4      0.0  192.0               0.0
# ...      ...                 ...      ...    ...               ...
# 1025   276.4               116.0     90.3  179.6               8.9
# 1026   322.2                 0.0    115.6  196.0              10.4
# 1027   148.5               139.4    108.6  192.7               6.1
# 1028   159.1               186.7      0.0  175.6              11.3
# 1029   260.9               100.5     78.3  200.6               8.6
#
#       Coarse Aggregate  Fine Aggregate  Age  Concrete compressive strength
# 0               1040.0           676.0   28                          79.99
# ...

# %%
# Description about the data
df.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# ...

# %%
# Information about data storage type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Cement                         1030 non-null   float64
#  1   Blast Furnace Slag             1030 non-null   float64
#  2   Fly Ash                        1030 non-null   float64
#  3   Water                          1030 non-null   float64
#  4   Superplasticizer               1030 non-null   float64
#  5   Coarse Aggregate               1030 non-null   float64
#  6   Fine Aggregate                 1030 non-null   float64
#  7   Age                            1030 non-null   int64
#  8   Concrete compressive strength  1030 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 72.5 KB

# %%
# Size of the data (rows, columns)
df.shape
# Out:
# (1030, 9)

# %%
df.nunique(0).sum() # number of unique values in axis=0
# Out:
# 2370

# %%
# Checking for duplicates values in dataset
df.duplicated().sum()
# Out:
# 25

# %%
# Checking for null values in dataset
df.isnull().sum() # null values are not found in this dataset
# Out:
# Cement                           0
# Blast Furnace Slag               0
# Fly Ash                          0
# Water                            0
# Superplasticizer                 0
# Coarse Aggregate                 0
# Fine Aggregate                   0
# Age                              0
# Concrete compressive strength    0
# dtype: int64

# %%
# Deleting duplicate values
df.drop_duplicates(keep="first", inplace=True)

# %%
# Now duplcate values are deleted (No duplicate value are found)
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # EDA (Exploratory Data Analysis)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.scatter(df["Cement"], df["Superplasticizer"], c=df["Age"])

# %%
# Scatter plot of the dataset
sns.scatterplot(x="Cement", y="Superplasticizer", data=df, hue='Age')
# Out:
# <Axes: xlabel='Cement', ylabel='Superplasticizer'>

# %% [markdown]
# # Relation between all columns

# %%
sns.pairplot(df, hue="Age") # Relation between all columns in a dataset
# We can see that independendly all columns are almost normnaly distributed
'''
It means that each feature follows a normal (Gaussian) distribution individually. This implies that the values of each column cluster around the mean with symmetrical spread, and the relationships between columns might still vary, but individually, each column behaves as a bell-shaped curve.
'''

# %% [markdown]
# # Correlation

# %%
# Displaying the correlation between all columns
sns.heatmap(df.corr(), annot = True)
# As we can see that there is no multicolinearity in the dataset
'''
It means that none of the independent features are highly correlated with each other. In other words, each feature provides unique information without redundancy, and no two or more columns have a linear relationship
'''
# Out:
# <Axes: >

# %% [markdown]
# # 3D Visualisation

# %%
# Visualising the data in 3D
import plotly.express as px
import plotly.graph_objects as go
fig = px.scatter_3d(df, x='Cement', y='Superplasticizer', z='Age')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Outliers

# %%
# Checking Outliers using Boxplot.
plt.figure(figsize = (15,15), facecolor = 'white')
plotnumber = 1
for i in df.columns:
 ax = plt.subplot(4,3, plotnumber)
 sns.boxplot(df[i])
 plt.xlabel(i, fontsize = 10)
 plotnumber +=1
plt.tight_layout()
plt.show()

# %% [markdown]
# # Removing outliers using IQR (Interquartile Range)

# %%
# Removing outliers using IQR (Interquartile Range) based filtering
# Columns That have outliers
outliers = ['Blast Furnace Slag','Water', 'Superplasticizer', 'Fine Aggregate', 'Age']
def outlier_capping(dataframe: pd.DataFrame, outliers:list):
 df = dataframe.copy()
 for i in outliers:
  q1 = df[i].quantile(0.25)
  q3 = df[i].quantile(0.75)
  iqr = q3 - q1
  upper_limit = q3 + 1.5 *iqr
  lower_limit = q3 - 1.5 *iqr
  df.loc[df[i] >upper_limit, i] = upper_limit
  df.loc[df[i] <lower_limit, i] = lower_limit
 return df
df = outlier_capping(dataframe = df, outliers = outliers)

# %%
# Checking Outliers
plt.figure(figsize = (15,15), facecolor = 'white')
plotnumber = 1
for i in df.columns:
 ax = plt.subplot(4,3, plotnumber)
 sns.boxplot(df[i])
 plt.xlabel(i, fontsize = 10)
 plotnumber +=1
plt.tight_layout()
plt.show()
# As we can see that there is not outliers now in the dataset

# %% [markdown]
# # Correlation after removing outliers

# %%
sns.heatmap(df.corr(), annot = True)
# Out:
# <Axes: >

# %% [markdown]
# # Training & Testing of model

# %%
# importing libraries to train and test the data
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# Spliting the training and testing data
x = df.iloc[:, :-1]
y = df.iloc[:, -1]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=40)

# %%
# Data is splitted into train data and test data
x_train.shape, x_test.shape
# Out:
# ((804, 8), (201, 8))

# %%
lr = LinearRegression()

# %%
# Training the model with trian data using linear regression model
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Predicting the data
y_pred = lr.predict(x_test)

# %% [markdown]
# # Errors and Accuracy of the trained data

# %%
# Errors and Accuracy of the trained data
print(f"MAE = {mean_absolute_error(y_test, y_pred):.3f}")
print(f"MSE = {mean_squared_error(y_test, y_pred):.3f}")
print(f"RMSE = {np.sqrt(mean_squared_error(y_test, y_pred)):.3f}")
print(f"R2 Score = {r2_score(y_test, y_pred)*100:.3f}%") # Accuracy of the model
# Out:
# MAE = 6.485
# MSE = 72.856
# RMSE = 8.536
# R2 Score = 71.487%

# %%
lr.coef_ # weight coefficients [b1, b2, ...] of the multilinear regression equation
# Out:
# array([ 0.09487911,  0.07369929,  0.04959439, -0.26800375,  0.22333152,
#        -0.01147555, -0.01767564,  0.25366065])

# %%
lr.intercept_ # y-intercept 'b0' of the multilinear regression equation
# Out:
# 63.52146920453938

# %% [markdown]
# # Assumptions Of Linear Regression

# %%
# Mean Residuals
# One of the assumptions of linear regression is that the mean of the residuals should be zero. So let's find out
residuals = y_test.values-y_pred
mean_residuals = np.mean(residuals)
print(f"Mean of Residuals {mean_residuals:.3f}")
# Out:
# Mean of Residuals 0.980

# %%
#  Independent features are Distributed Normally
# Box-cox method
from sklearn.preprocessing import PowerTransformer
pt = PowerTransformer(method='box-cox')
df_trans1 = pd.DataFrame(pt.fit_transform(df+0.000001),columns=df.columns)
plt.figure(figsize=(15,15),facecolor='white')
plotnumber = 1
for i in df.columns:
 ax = plt.subplot(4,3,plotnumber)
 sns.histplot(df_trans1[i])
 plt.xlabel(i,fontsize=10)
 plotnumber+=1
plt.tight_layout()
plt.show()
print(df_trans1.skew())
# Out:
# Cement                          -0.012649
# Blast Furnace Slag              -0.114416
# Fly Ash                          0.155235
# Water                            0.011402
# Superplasticizer                -0.489456
# Coarse Aggregate                -0.020292
# Fine Aggregate                   0.007200
# Age                             -0.055427
# Concrete compressive strength   -0.059105
# dtype: float64

# %% [markdown]
# # Linear Regression Model using Scikit- Learn

# %%
# Splitting data in independent features and dependent feature
X1 = df_trans1.iloc[:,:-1]
y1 = df_trans1.iloc[:,-1]
# Splitting the data in trainning data and test data
X_train1,X_test1,y_train1,y_test1 = train_test_split(X1,y1,test_size=0.2,random_state=42)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train1_scaled = scaler.fit_transform(X_train1)
X_test1_scaled = scaler.transform(X_test1)

# %%
lrm = LinearRegression()
lrm.fit(X_train1_scaled,y_train1)
y_pred1 = lrm.predict(X_test1_scaled)
R_Square1 = r2_score(y_test1,y_pred1)
print(f"Accuracy of the model without checking assumption of linear regression is {r2_score(y_test, y_pred) * 100:.3f}%")
print(f"Accuracy of the model after checking assumption of the linear regression model is {R_Square1*100:.3f}%")
# Out:
# Accuracy of the model without checking assumption of linear regression is 71.487%
# Accuracy of the model after checking assumption of the linear regression model is 82.837%

# %% [markdown]
# # Stochastic Gradient Class using Scikit-Learn

# %%
from sklearn.linear_model import SGDRegressor
sgd = SGDRegressor()
sgd.fit(X_train1_scaled,y_train1)
y_pred5 = sgd.predict(X_test1_scaled)
r2_score(y_test,y_pred5)
# Out:
# -5.441411694805992

# %%
sgd.coef_ # weight coefficients b1, b2... of the multilinear regression equation
# Out:
# array([ 0.46067226,  0.20617412, -0.04309689, -0.32823108,  0.16346976,
#        -0.08131254, -0.17220788,  0.61194912])

# %%
sgd.intercept_ # y-intercept b0 of the multilinear regression equation
# Out:
# array([-0.00435797])

# %% [markdown]
# # Conclusion
# ## 1. Check Duplicated values and handle it
# 25 duplicated values in this dataset
# ## 2. Detect Outliers
# Detect outlier by Box plot.
#
# Outliers present in this dataset .So I fix outlies by Interquartile Range method
#
# **Interquartile Range (IQR):** IQR identifies outliers as data points falling outside the range defined
# by **"Q1-k*(Q3- Q1) and Q3+k*(Q3-Q1)"**, where **Q1** and **Q3** are the ***first and third quartiles***, and **k** is a
# **factor** (typically 1.5).
# ## 3. Independent features are not normally distributed in this dataset. Therefore,
# Box-Cox method was applied to find independent features that are normally
# distributed.
# ## 4. Feature Scaling
# Feature Scaling is a technique to standardize the independent features present in the data in a fixed range. It is performed during the data pre-processing to handle highly varying magnitudes
# or values or units. If feature scaling is not done, then a machine learning algorithm tends to
# weigh greater values, higher and consider smaller values as the lower values, regardless of the
# unit of the values.
#
# "When I applied linear regression algorithm without any correction
# in dataset, then the accuracy of my model was 71 percent. But
# when I did the points given above, the accuracy of my model went
# up to 82 percent."

# %%
print(f"Accuracy of the model without checking assumption of linear regression is {r2_score(y_test, y_pred) * 100:.3f}%")
print(f"Accuracy of the model after checking assumption of the linear regression model is {R_Square1*100:.3f}%")
# Out:
# Accuracy of the model without checking assumption of linear regression is 71.487%
# Accuracy of the model after checking assumption of the linear regression model is 82.837%
